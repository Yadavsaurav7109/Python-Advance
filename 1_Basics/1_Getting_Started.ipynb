# %%
2 + 2
# Out:
# 4

# %%
2 + 2
# Out:
# 4

# %%
print(2 + 3)
print(2 + 2)
# Out:
# 5
# 4

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 303 µs ± 3.96 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 381 µs ± 80.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
